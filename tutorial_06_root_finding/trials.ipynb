# %%
import numpy as np 
omega = 2*np.pi/365
print(omega)
import matplotlib.pyplot as plt
# Out:
# 0.01721420632103996

# %%
T = 365.2635
a = 1.496e16
e = 0.9999
omega = 2*np.pi/T
t=273

def f(x):
    return (omega*t + e*np.sin(x)-x)
x = np.linspace(-2.5,5)
plt.grid()
plt.plot(x,f(x))
plt.show()

# %%
def f(x):
    return(np.tan(x)-1/x)
x = np.linspace(0,1)
plt.grid()
plt.plot(x,f(x))
